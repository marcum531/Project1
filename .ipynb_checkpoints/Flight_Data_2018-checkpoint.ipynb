# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
Jan_2018 = "flight_csv_files/Jan_2018.csv"
Feb_2018 = "flight_csv_files/Feb_2018.csv"
Mar_2018 = "flight_csv_files/Mar_2018.csv"
Apr_2018 = "flight_csv_files/Apr_2018.csv"
May_2018 = "flight_csv_files/May_2018.csv"
Jun_2018 = "flight_csv_files/Jun_2018.csv"
Jul_2018 = "flight_csv_files/Jul_2018.csv"
Aug_2018 = "flight_csv_files/Aug_2018.csv"
Sep_2018 = "flight_csv_files/Sep_2018.csv"
Oct_2018 = "flight_csv_files/Oct_2018.csv"
Nov_2018 = "flight_csv_files/Nov_2018.csv"
Dec_2018 = "flight_csv_files/Dec_2018.csv"

# %%
Jan_2018_data=pd.read_csv(Jan_2018)
Feb_2018_data=pd.read_csv(Feb_2018)
Mar_2018_data=pd.read_csv(Mar_2018)
Apr_2018_data=pd.read_csv(Apr_2018)
May_2018_data=pd.read_csv(May_2018)
Jun_2018_data=pd.read_csv(Jun_2018)
Jul_2018_data=pd.read_csv(Jul_2018)
Aug_2018_data=pd.read_csv(Aug_2018)
Sep_2018_data=pd.read_csv(Sep_2018)
Oct_2018_data=pd.read_csv(Oct_2018)
Nov_2018_data=pd.read_csv(Nov_2018)
Dec_2018_data=pd.read_csv(Dec_2018)

# %%
Jan_Feb_2018 = Jan_2018_data.append(Feb_2018_data)
Jan_Feb_Mar_2018 = Jan_Feb_2018.append(Mar_2018_data)
Mar_Apr_2018 = Jan_Feb_Mar_2018.append(Apr_2018_data)
Mar_Apr_Jun_2018 = Mar_Apr_2018.append(Jun_2018_data)
Jun_Jul_2018 = Mar_Apr_Jun_2018.append(Jul_2018_data)
Jun_Jul_Aug_2018 = Jun_Jul_2018.append(Aug_2018_data)
Aug_Sep_2018 = Jun_Jul_Aug_2018.append(Sep_2018_data)
Aug_Sep_Oct_2018 = Aug_Sep_2018.append(Oct_2018_data)
Oct_Nov_2018 = Aug_Sep_Oct_2018.append(Nov_2018_data)
year_2018 = Oct_Nov_2018.append(Dec_2018_data)
year_2018
# Out:
#            FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 0         1/1/2018                9E    TVC      Traverse City, MI  DTW
# 1         1/1/2018                9E    OMA              Omaha, NE  DTW
# 2         1/1/2018                9E    MSP        Minneapolis, MN  BIS
# 3         1/1/2018                9E    IND       Indianapolis, IN  RSW
# 4         1/1/2018                9E    RSW         Fort Myers, FL  IND
# ...            ...               ...    ...                    ...  ...
# 593837  12/31/2018                AA    ORD            Chicago, IL  SAN
# 593838  12/31/2018                AA    LGA           New York, NY  MIA
# 593839  12/31/2018                AA    ORD            Chicago, IL  BOS
# 593840  12/31/2018                AA    DFW  Dallas/Fort Worth, TX  SMF
# 593841  12/31/2018                AA    ORD            Chicago, IL  SFO
#
#              DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# ...

# %%
Cleveland_2018 = year_2018.loc[(year_2018['ORIGIN']=='CLE') | (year_2018['DEST']=='CLE')]
Cleveland_2018
# Out:
#            FL_DATE OP_UNIQUE_CARRIER ORIGIN  ORIGIN_CITY_NAME DEST  \
# 248       1/1/2018                B6    CLE     Cleveland, OH  BOS
# 249       1/1/2018                B6    BOS        Boston, MA  CLE
# 347       1/1/2018                B6    CLE     Cleveland, OH  BOS
# 348       1/1/2018                B6    BOS        Boston, MA  CLE
# 358       1/1/2018                B6    CLE     Cleveland, OH  FLL
# ...            ...               ...    ...               ...  ...
# 592470  12/31/2018                OO    DTW       Detroit, MI  CLE
# 593428  12/31/2018                AA    CLE     Cleveland, OH  PHL
# 593530  12/31/2018                AA    PHL  Philadelphia, PA  CLE
# 593711  12/31/2018                AA    CLE     Cleveland, OH  CLT
# 593712  12/31/2018                AA    CLT     Charlotte, NC  CLE
#
#              DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 248              Boston, MA          1022       -7.0            0.0    1214.0
# ...

# %%
Cleveland_2018.count()
# Out:
# FL_DATE                88536
# OP_UNIQUE_CARRIER      88536
# ORIGIN                 88536
# ORIGIN_CITY_NAME       88536
# DEST                   88536
# DEST_CITY_NAME         88536
# CRS_DEP_TIME           88536
# DEP_DELAY              86627
# DEP_DELAY_NEW          86627
# ARR_TIME               86680
# ARR_DELAY              86464
# ARR_DELAY_NEW          86464
# CANCELLED              88536
# CARRIER_DELAY          16125
# WEATHER_DELAY          16125
# NAS_DELAY              16125
# SECURITY_DELAY         16125
# LATE_AIRCRAFT_DELAY    16125
# dtype: int64

# %%
Cleveland_2018.to_csv('Cleveland_2018.csv', encoding='utf-8', index=False)
