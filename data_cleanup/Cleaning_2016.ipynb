# %%
import pandas as pd

# %%
data_df=pd.read_csv("./cleaned_csvs/cle_flights_2016.csv")

# %%
data_df['year'] = pd.DatetimeIndex(data_df['FL_DATE']).year
# data_df.head()

# %%
data_df['month'] = pd.DatetimeIndex(data_df['FL_DATE']).month
# data_df.head()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68220 entries, 0 to 68219
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           68220 non-null  int64
#  1   MONTH                68220 non-null  int64
#  2   FL_DATE              68220 non-null  object
#  3   OP_UNIQUE_CARRIER    68220 non-null  object
#  4   ORIGIN               68220 non-null  object
#  5   ORIGIN_CITY_NAME     68220 non-null  object
#  6   DEST                 68220 non-null  object
#  7   DEST_CITY_NAME       68220 non-null  object
#  8   CRS_DEP_TIME         68220 non-null  int64
#  9   DEP_DELAY            67300 non-null  float64
#  10  DEP_DELAY_NEW        67300 non-null  float64
#  11  CRS_ARR_TIME         68220 non-null  int64
#  12  ARR_TIME             67243 non-null  float64
#  13  ARR_DELAY            67134 non-null  float64
#  14  ARR_DELAY_NEW        67134 non-null  float64
# ...

# %%
# Delete Unwated Columns

del data_df['Unnamed: 0']
del data_df['Unnamed: 21']
del data_df['CRS_ARR_TIME']
del data_df['MONTH']
del data_df['CANCELLATION_CODE']

# %%
data_df
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 0      2016-04-01                AA    DFW  Dallas/Fort Worth, TX  CLE
# 1      2016-04-02                AA    DFW  Dallas/Fort Worth, TX  CLE
# 2      2016-04-03                AA    DFW  Dallas/Fort Worth, TX  CLE
# 3      2016-04-04                AA    DFW  Dallas/Fort Worth, TX  CLE
# 4      2016-04-05                AA    DFW  Dallas/Fort Worth, TX  CLE
# ...           ...               ...    ...                    ...  ...
# 68215  2016-12-31                WN    MDW            Chicago, IL  CLE
# 68216  2016-12-31                WN    MDW            Chicago, IL  CLE
# 68217  2016-12-31                WN    MDW            Chicago, IL  CLE
# 68218  2016-12-31                WN    PHX            Phoenix, AZ  CLE
# 68219  2016-12-31                WN    PHX            Phoenix, AZ  CLE
#
#       DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# ...

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68220 entries, 0 to 68219
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              68220 non-null  object
#  1   OP_UNIQUE_CARRIER    68220 non-null  object
#  2   ORIGIN               68220 non-null  object
#  3   ORIGIN_CITY_NAME     68220 non-null  object
#  4   DEST                 68220 non-null  object
#  5   DEST_CITY_NAME       68220 non-null  object
#  6   CRS_DEP_TIME         68220 non-null  int64
#  7   DEP_DELAY            67300 non-null  float64
#  8   DEP_DELAY_NEW        67300 non-null  float64
#  9   ARR_TIME             67243 non-null  float64
#  10  ARR_DELAY            67134 non-null  float64
#  11  ARR_DELAY_NEW        67134 non-null  float64
#  12  CANCELLED            68220 non-null  float64
#  13  CARRIER_DELAY        11356 non-null  float64
#  14  WEATHER_DELAY        11356 non-null  float64
# ...

# %%
data_df.to_csv("./Clean/Data_2016.csv")
