# %%
# Dependencies and Setup

import pandas as pd

# %%
# File to Load (Remember to Change These)

Jan_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Jan2017.csv"
Feb_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Feb2017.csv"
Mar_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Mar2017.csv"
Apr_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Apr2017.csv"
May_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/May2017.csv"
Jun_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Jun2017.csv"
Jul_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Jul2017.csv"
Aug_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Aug2017.csv"
Sep_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Sep2017.csv"
Oct_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Oct2017.csv"
Nov_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Nov2017.csv"
Dec_load = "/Users/diegogonzalez/Desktop/Data Science/Project1/Flightstats/Dec2017.csv"

# Read School and Student Data File and store into Pandas DataFrames

Jan = pd.read_csv(Jan_load)
Feb = pd.read_csv(Feb_load)
Mar = pd.read_csv(Mar_load)
Apr = pd.read_csv(Apr_load)
May = pd.read_csv(May_load)
Jun = pd.read_csv(Jun_load)
Jul = pd.read_csv(Jul_load)
Aug = pd.read_csv(Aug_load)
Sep = pd.read_csv(Sep_load)
Oct = pd.read_csv(Oct_load)
Nov = pd.read_csv(Nov_load)
Dec = pd.read_csv(Dec_load)

# %%
# # Combine the data into a single dataset 
# school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
# school_data_complete.head()
Jan
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN     ORIGIN_CITY_NAME DEST  \
# 0      2017-01-01                EV    IAH          Houston, TX  CLE
# 1      2017-01-01                EV    IAH          Houston, TX  CLE
# 2      2017-01-01                EV    IAH          Houston, TX  CMH
# 3      2017-01-01                EV    CLE        Cleveland, OH  EWR
# 4      2017-01-01                EV    EWR           Newark, NJ  CMH
# ...           ...               ...    ...                  ...  ...
# 10737  2017-01-31                B6    BOS           Boston, MA  CLE
# 10738  2017-01-31                B6    CLE        Cleveland, OH  BOS
# 10739  2017-01-31                B6    BOS           Boston, MA  CLE
# 10740  2017-01-31                B6    CLE        Cleveland, OH  FLL
# 10741  2017-01-31                B6    FLL  Fort Lauderdale, FL  CLE
#
#             DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# ...

# %%
jan_cle=Jan.loc[(Jan["ORIGIN"] =="CLE") | (Jan["DEST"] =="CLE")]
jan_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN     ORIGIN_CITY_NAME DEST  \
# 0      2017-01-01                EV    IAH          Houston, TX  CLE
# 1      2017-01-01                EV    IAH          Houston, TX  CLE
# 3      2017-01-01                EV    CLE        Cleveland, OH  EWR
# 8      2017-01-01                EV    CLE        Cleveland, OH  IAH
# 9      2017-01-01                EV    CLE        Cleveland, OH  EWR
# ...           ...               ...    ...                  ...  ...
# 10737  2017-01-31                B6    BOS           Boston, MA  CLE
# 10738  2017-01-31                B6    CLE        Cleveland, OH  BOS
# 10739  2017-01-31                B6    BOS           Boston, MA  CLE
# 10740  2017-01-31                B6    CLE        Cleveland, OH  FLL
# 10741  2017-01-31                B6    FLL  Fort Lauderdale, FL  CLE
#
#             DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# ...

# %%
feb_cle=Feb.loc[(Feb["ORIGIN"] =="CLE") | (Feb["DEST"] =="CLE")]
feb_cle
# Out:
#          FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 3     2017-02-01                DL    ATL      Atlanta, GA  CLE
# 4     2017-02-01                DL    CLE    Cleveland, OH  ATL
# 5     2017-02-01                DL    CLE    Cleveland, OH  ATL
# 14    2017-02-01                DL    ATL      Atlanta, GA  CLE
# 28    2017-02-01                DL    ATL      Atlanta, GA  CLE
# ...          ...               ...    ...              ...  ...
# 9820  2017-02-28                NK    CLE    Cleveland, OH  LAX
# 9821  2017-02-28                NK    CLE    Cleveland, OH  ATL
# 9822  2017-02-28                NK    ATL      Atlanta, GA  CLE
# 9825  2017-02-28                NK    RSW   Fort Myers, FL  CLE
# 9826  2017-02-28                NK    CLE    Cleveland, OH  RSW
#
#        DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 3       Cleveland, OH          1031       -4.0            0.0    1201.0
# ...

# %%
mar_cle=Mar.loc[(Mar["ORIGIN"] =="CLE") | (Mar["DEST"] =="CLE")]
mar_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 2      2017-03-01                NK    MCO      Orlando, FL  CLE
# 3      2017-03-01                NK    CLE    Cleveland, OH  MCO
# 4      2017-03-01                F9    TPA        Tampa, FL  CLE
# 5      2017-03-01                F9    CLE    Cleveland, OH  TPA
# 6      2017-03-01                F9    MCO      Orlando, FL  CLE
# ...           ...               ...    ...              ...  ...
# 11730  2017-03-31                EV    CLE    Cleveland, OH  LGA
# 11733  2017-03-31                AA    CLE    Cleveland, OH  CLT
# 11734  2017-03-31                AA    CLE    Cleveland, OH  CLT
# 11735  2017-03-31                AA    CLT    Charlotte, NC  CLE
# 11736  2017-03-31                AA    CLT    Charlotte, NC  CLE
#
#       DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 2      Cleveland, OH          1122       24.0           24.0    1408.0
# ...

# %%
apr_cle=Apr.loc[(Apr["ORIGIN"] =="CLE") | (Apr["DEST"] =="CLE")]
apr_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 0      2017-04-01                UA    CLE    Cleveland, OH  FLL
# 3      2017-04-01                UA    DEN       Denver, CO  CLE
# 4      2017-04-01                UA    SJU     San Juan, PR  CLE
# 5      2017-04-01                UA    CLE    Cleveland, OH  SJU
# 6      2017-04-01                AA    CLE    Cleveland, OH  DFW
# ...           ...               ...    ...              ...  ...
# 11984  2017-04-30                EV    DCA   Washington, DC  CLE
# 11985  2017-04-30                EV    DCA   Washington, DC  CLE
# 12007  2017-04-30                OO    CLE    Cleveland, OH  ORD
# 12012  2017-04-30                OO    CLE    Cleveland, OH  ORD
# 12013  2017-04-30                OO    ORD      Chicago, IL  CLE
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# 0        Fort Lauderdale, FL           735       18.0           18.0
# ...

# %%
may_cle=May.loc[(May["ORIGIN"] =="CLE") | (May["DEST"] =="CLE")]
may_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 38     2017-05-01                OO    CLE          Cleveland, OH  ORD
# 39     2017-05-01                OO    ORD            Chicago, IL  CLE
# 44     2017-05-01                AA    CLE          Cleveland, OH  DFW
# 45     2017-05-01                AA    DFW  Dallas/Fort Worth, TX  CLE
# 46     2017-05-01                B6    CLE          Cleveland, OH  BOS
# ...           ...               ...    ...                    ...  ...
# 12434  2017-05-31                EV    CLE          Cleveland, OH  LGA
# 12435  2017-05-31                EV    LGA           New York, NY  CLE
# 12436  2017-05-31                EV    CLE          Cleveland, OH  LGA
# 12437  2017-05-31                EV    CLE          Cleveland, OH  MSP
# 12438  2017-05-31                EV    CLE          Cleveland, OH  LGA
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# ...

# %%
jun_cle=Jun.loc[(Jun["ORIGIN"] =="CLE") | (Jun["DEST"] =="CLE")]
jun_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 11     2017-06-01                DL    ATL            Atlanta, GA  CLE
# 12     2017-06-01                DL    CLE          Cleveland, OH  ATL
# 25     2017-06-01                DL    ATL            Atlanta, GA  CLE
# 26     2017-06-01                DL    CLE          Cleveland, OH  ATL
# 27     2017-06-01                DL    ATL            Atlanta, GA  CLE
# ...           ...               ...    ...                    ...  ...
# 12451  2017-06-30                AA    DFW  Dallas/Fort Worth, TX  CLE
# 12458  2017-06-30                AA    CLE          Cleveland, OH  DFW
# 12459  2017-06-30                AA    DFW  Dallas/Fort Worth, TX  CLE
# 12460  2017-06-30                AA    CLE          Cleveland, OH  DFW
# 12461  2017-06-30                AA    DFW  Dallas/Fort Worth, TX  CLE
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# ...

# %%
jul_cle=Jul.loc[(Jul["ORIGIN"] =="CLE") | (Jul["DEST"] =="CLE")]
jul_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN  ORIGIN_CITY_NAME DEST  \
# 0      2017-07-01                AA    CLE     Cleveland, OH  DFW
# 4      2017-07-01                UA    CLE     Cleveland, OH  IAH
# 5      2017-07-01                UA    MCO       Orlando, FL  CLE
# 6      2017-07-01                UA    EWR        Newark, NJ  CLE
# 7      2017-07-01                UA    LAX   Los Angeles, CA  CLE
# ...           ...               ...    ...               ...  ...
# 12556  2017-07-31                NK    CLE     Cleveland, OH  LAX
# 12557  2017-07-31                NK    CLE     Cleveland, OH  MYR
# 12558  2017-07-31                NK    MYR  Myrtle Beach, SC  CLE
# 12559  2017-07-31                NK    CLE     Cleveland, OH  ATL
# 12560  2017-07-31                NK    ATL       Atlanta, GA  CLE
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# 0      Dallas/Fort Worth, TX           719        9.0            9.0
# ...

# %%
aug_cle=Aug.loc[(Aug["ORIGIN"] =="CLE") | (Aug["DEST"] =="CLE")]
aug_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 0      2017-08-01                AA    CLE          Cleveland, OH  DFW
# 1      2017-08-01                AA    DFW  Dallas/Fort Worth, TX  CLE
# 2      2017-08-01                AA    CLT          Charlotte, NC  CLE
# 4      2017-08-01                AA    CLE          Cleveland, OH  CLT
# 5      2017-08-01                AA    CLT          Charlotte, NC  CLE
# ...           ...               ...    ...                    ...  ...
# 12855  2017-08-31                F9    RSW         Fort Myers, FL  CLE
# 12856  2017-08-31                F9    ATL            Atlanta, GA  CLE
# 12857  2017-08-31                F9    CLE          Cleveland, OH  MSP
# 12860  2017-08-31                F9    MSP        Minneapolis, MN  CLE
# 12861  2017-08-31                F9    CLE          Cleveland, OH  ATL
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# ...

# %%
sep_cle=Sep.loc[(Sep["ORIGIN"] =="CLE") | (Sep["DEST"] =="CLE")]
sep_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 5      2017-09-01                DL    ATL      Atlanta, GA  CLE
# 6      2017-09-01                DL    CLE    Cleveland, OH  ATL
# 17     2017-09-01                DL    ATL      Atlanta, GA  CLE
# 18     2017-09-01                DL    DTW      Detroit, MI  CLE
# 19     2017-09-01                DL    ATL      Atlanta, GA  CLE
# ...           ...               ...    ...              ...  ...
# 12027  2017-09-30                WN    DEN       Denver, CO  CLE
# 12030  2017-09-30                WN    LAS    Las Vegas, NV  CLE
# 12035  2017-09-30                WN    MDW      Chicago, IL  CLE
# 12036  2017-09-30                WN    MDW      Chicago, IL  CLE
# 12037  2017-09-30                WN    MDW      Chicago, IL  CLE
#
#       DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 5      Cleveland, OH          1426       42.0           42.0    1636.0
# ...

# %%
oct_cle=Oct.loc[(Oct["ORIGIN"] =="CLE") | (Oct["DEST"] =="CLE")]
oct_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN    ORIGIN_CITY_NAME DEST  \
# 1      2017-10-01                AA    CLE       Cleveland, OH  DFW
# 2      2017-10-01                F9    CLE       Cleveland, OH  SFO
# 4      2017-10-01                F9    SFO   San Francisco, CA  CLE
# 5      2017-10-01                F9    CLE       Cleveland, OH  RDU
# 6      2017-10-01                F9    RDU  Raleigh/Durham, NC  CLE
# ...           ...               ...    ...                 ...  ...
# 12393  2017-10-31                EV    CLE       Cleveland, OH  LGA
# 12394  2017-10-31                EV    CLE       Cleveland, OH  RDU
# 12395  2017-10-31                EV    CLE       Cleveland, OH  LGA
# 12396  2017-10-31                EV    CLE       Cleveland, OH  LGA
# 12399  2017-10-31                AA    CLT       Charlotte, NC  CLE
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# 1      Dallas/Fort Worth, TX           724        0.0            0.0
# ...

# %%
nov_cle=Nov.loc[(Nov["ORIGIN"] =="CLE") | (Nov["DEST"] =="CLE")]
nov_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 0      2017-11-01                UA    ORD            Chicago, IL  CLE
# 1      2017-11-01                UA    CLE          Cleveland, OH  ORD
# 3      2017-11-01                UA    EWR             Newark, NJ  CLE
# 4      2017-11-01                UA    CLE          Cleveland, OH  EWR
# 5      2017-11-01                UA    EWR             Newark, NJ  CLE
# ...           ...               ...    ...                    ...  ...
# 11870  2017-11-30                EV    DCA         Washington, DC  CLE
# 11872  2017-11-30                EV    CLE          Cleveland, OH  IAH
# 11873  2017-11-30                AA    CLE          Cleveland, OH  DFW
# 11878  2017-11-30                AA    DFW  Dallas/Fort Worth, TX  CLE
# 11879  2017-11-30                AA    CLE          Cleveland, OH  CLT
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# ...

# %%
dec_cle=Dec.loc[(Dec["ORIGIN"] =="CLE") | (Dec["DEST"] =="CLE")]
dec_cle
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN       ORIGIN_CITY_NAME DEST  \
# 0      2017-12-01                AA    DFW  Dallas/Fort Worth, TX  CLE
# 1      2017-12-01                AA    CLE          Cleveland, OH  DFW
# 14     2017-12-01                F9    CLE          Cleveland, OH  TPA
# 15     2017-12-01                F9    TPA              Tampa, FL  CLE
# 16     2017-12-01                F9    CLE          Cleveland, OH  PHX
# ...           ...               ...    ...                    ...  ...
# 11453  2017-12-31                EV    MSP        Minneapolis, MN  CLE
# 11454  2017-12-31                EV    CLE          Cleveland, OH  LGA
# 11455  2017-12-31                EV    LGA           New York, NY  CLE
# 11456  2017-12-31                EV    CLE          Cleveland, OH  DTW
# 11457  2017-12-31                EV    DTW            Detroit, MI  CLE
#
#               DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  \
# ...

# %%
# saving clean files as csv
jan_cle.to_csv('Jan_2017.csv')
feb_cle.to_csv('Feb_2017.csv')
mar_cle.to_csv('Mar_2017.csv')
apr_cle.to_csv('Apr_2017.csv')
may_cle.to_csv('May_2017.csv')
jun_cle.to_csv('Jun_2017.csv')
jul_cle.to_csv('Jul_2017.csv')
aug_cle.to_csv('Aug_2017.csv')
sep_cle.to_csv('Sep_2017.csv')
oct_cle.to_csv('Oct_2017.csv')
nov_cle.to_csv('Nov_2017.csv')
dec_cle.to_csv('Dec_2017.csv')

# %%
# Combine the data into a single dataset 
jan_feb_2017=jan_cle.append(feb_cle)
feb_mar_2017=jan_feb_2017.append(mar_cle)
mar_apr_2017=feb_mar_2017.append(apr_cle)
apr_may_2017=mar_apr_2017.append(may_cle)
may_jun_2017=apr_may_2017.append(jun_cle)
jun_jul_2017=may_jun_2017.append(jul_cle)
jul_aug_2017=jun_jul_2017.append(aug_cle)
aug_sep_2017=jul_aug_2017.append(sep_cle)
sep_oct_2017=aug_sep_2017.append(oct_cle)
oct_nov_2017=sep_oct_2017.append(nov_cle)
data2017=oct_nov_2017.append(dec_cle)
data2017
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 0      2017-01-01                EV    IAH      Houston, TX  CLE
# 1      2017-01-01                EV    IAH      Houston, TX  CLE
# 3      2017-01-01                EV    CLE    Cleveland, OH  EWR
# 8      2017-01-01                EV    CLE    Cleveland, OH  IAH
# 9      2017-01-01                EV    CLE    Cleveland, OH  EWR
# ...           ...               ...    ...              ...  ...
# 11453  2017-12-31                EV    MSP  Minneapolis, MN  CLE
# 11454  2017-12-31                EV    CLE    Cleveland, OH  LGA
# 11455  2017-12-31                EV    LGA     New York, NY  CLE
# 11456  2017-12-31                EV    CLE    Cleveland, OH  DTW
# 11457  2017-12-31                EV    DTW      Detroit, MI  CLE
#
#       DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 0      Cleveland, OH          1935       -4.0            0.0    2258.0
# ...

# %%
data2017.count()
# Out:
# FL_DATE                71272
# OP_UNIQUE_CARRIER      71272
# ORIGIN                 71272
# ORIGIN_CITY_NAME       71272
# DEST                   71272
# DEST_CITY_NAME         71272
# CRS_DEP_TIME           71272
# DEP_DELAY              70245
# DEP_DELAY_NEW          70245
# ARR_TIME               70201
# ARR_DELAY              70094
# ARR_DELAY_NEW          70094
# CANCELLED              71272
# CARRIER_DELAY          12195
# WEATHER_DELAY          12195
# NAS_DELAY              12195
# SECURITY_DELAY         12195
# LATE_AIRCRAFT_DELAY    12195
# Unnamed: 18                0
# dtype: int64

# %%
data2017.to_csv('Data_2017.csv')
