# %%
import pandas as pd

# %%
data_df=pd.read_csv("./cleaned_csvs/cle_flights_2020.csv")

# %%
data_df['year'] = pd.DatetimeIndex(data_df['FL_DATE']).year
# data_df.head()

# %%
data_df['month'] = pd.DatetimeIndex(data_df['FL_DATE']).month
# data_df.head()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22539 entries, 0 to 22538
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           22539 non-null  int64
#  1   MONTH                22539 non-null  int64
#  2   FL_DATE              22539 non-null  object
#  3   OP_UNIQUE_CARRIER    22539 non-null  object
#  4   ORIGIN               22539 non-null  object
#  5   ORIGIN_CITY_NAME     22539 non-null  object
#  6   DEST                 22539 non-null  object
#  7   DEST_CITY_NAME       22539 non-null  object
#  8   CRS_DEP_TIME         22539 non-null  int64
#  9   DEP_DELAY            21118 non-null  float64
#  10  DEP_DELAY_NEW        21118 non-null  float64
#  11  CRS_ARR_TIME         22539 non-null  int64
#  12  ARR_TIME             21115 non-null  float64
#  13  ARR_DELAY            21096 non-null  float64
#  14  ARR_DELAY_NEW        21096 non-null  float64
#  15  CANCELLED            22539 non-null  float64
#  16  CANCELLATION_CODE    1423 non-null   object
#  17  CARRIER_DELAY        2493 non-null   float64
#  18  WEATHER_DELAY        2493 non-null   float64
#  19  NAS_DELAY            2493 non-null   float64
#  20  SECURITY_DELAY       2493 non-null   float64
#  21  LATE_AIRCRAFT_DELAY  2493 non-null   float64
#  22  Unnamed: 21          0 non-null      float64
#  23  year                 22539 non-null  int64
#  24  month                22539 non-null  int64
# dtypes: float64(12), int64(6), object(7)
# memory usage: 4.3+ MB

# %%
# Delete Unwated Columns

del data_df['Unnamed: 0']
del data_df['Unnamed: 21']
del data_df['MONTH']
del data_df['CANCELLATION_CODE']
del data_df['CRS_ARR_TIME']

# %%
data_df
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN ORIGIN_CITY_NAME DEST  \
# 0      2020-01-01                WN    PHX      Phoenix, AZ  CLE
# 1      2020-01-01                WN    STL    St. Louis, MO  CLE
# 2      2020-01-01                WN    STL    St. Louis, MO  CLE
# 3      2020-01-02                WN    ATL      Atlanta, GA  CLE
# 4      2020-01-02                WN    ATL      Atlanta, GA  CLE
# ...           ...               ...    ...              ...  ...
# 22534  2020-03-11                UA    CLE    Cleveland, OH  DEN
# 22535  2020-03-11                UA    EWR       Newark, NJ  CLE
# 22536  2020-03-11                UA    CLE    Cleveland, OH  ORD
# 22537  2020-03-11                UA    CLE    Cleveland, OH  SFO
# 22538  2020-03-11                UA    CLE    Cleveland, OH  ORD
#
#           DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 0          Cleveland, OH          1305        6.0            6.0    1846.0
# 1          Cleveland, OH          1910       14.0           14.0    2144.0
# 2          Cleveland, OH           830       20.0           20.0    1103.0
# 3          Cleveland, OH           820        2.0            2.0    1000.0
# 4          Cleveland, OH          1645       20.0           20.0    1831.0
# ...                  ...           ...        ...            ...       ...
# 22534         Denver, CO          1115      -11.0            0.0    1217.0
# 22535      Cleveland, OH          1400       -4.0            0.0    1537.0
# 22536        Chicago, IL          1115      -10.0            0.0    1120.0
# 22537  San Francisco, CA          1921       -2.0            0.0    2131.0
# 22538        Chicago, IL           845       -7.0            0.0     903.0
#
#        ARR_DELAY  ARR_DELAY_NEW  CANCELLED  CARRIER_DELAY  WEATHER_DELAY  \
# 0           -4.0            0.0        0.0            NaN            NaN
# 1           -1.0            0.0        0.0            NaN            NaN
# 2            3.0            3.0        0.0            NaN            NaN
# 3            0.0            0.0        0.0            NaN            NaN
# 4            6.0            6.0        0.0            NaN            NaN
# ...          ...            ...        ...            ...            ...
# 22534      -19.0            0.0        0.0            NaN            NaN
# 22535        0.0            0.0        0.0            NaN            NaN
# 22536      -25.0            0.0        0.0            NaN            NaN
# 22537       -5.0            0.0        0.0            NaN            NaN
# 22538      -12.0            0.0        0.0            NaN            NaN
#
#        NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  year  month
# 0            NaN             NaN                  NaN  2020      1
# 1            NaN             NaN                  NaN  2020      1
# 2            NaN             NaN                  NaN  2020      1
# 3            NaN             NaN                  NaN  2020      1
# 4            NaN             NaN                  NaN  2020      1
# ...          ...             ...                  ...   ...    ...
# 22534        NaN             NaN                  NaN  2020      3
# 22535        NaN             NaN                  NaN  2020      3
# 22536        NaN             NaN                  NaN  2020      3
# 22537        NaN             NaN                  NaN  2020      3
# 22538        NaN             NaN                  NaN  2020      3
#
# [22539 rows x 20 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22539 entries, 0 to 22538
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              22539 non-null  object
#  1   OP_UNIQUE_CARRIER    22539 non-null  object
#  2   ORIGIN               22539 non-null  object
#  3   ORIGIN_CITY_NAME     22539 non-null  object
#  4   DEST                 22539 non-null  object
#  5   DEST_CITY_NAME       22539 non-null  object
#  6   CRS_DEP_TIME         22539 non-null  int64
#  7   DEP_DELAY            21118 non-null  float64
#  8   DEP_DELAY_NEW        21118 non-null  float64
#  9   ARR_TIME             21115 non-null  float64
#  10  ARR_DELAY            21096 non-null  float64
#  11  ARR_DELAY_NEW        21096 non-null  float64
#  12  CANCELLED            22539 non-null  float64
#  13  CARRIER_DELAY        2493 non-null   float64
#  14  WEATHER_DELAY        2493 non-null   float64
#  15  NAS_DELAY            2493 non-null   float64
#  16  SECURITY_DELAY       2493 non-null   float64
#  17  LATE_AIRCRAFT_DELAY  2493 non-null   float64
#  18  year                 22539 non-null  int64
#  19  month                22539 non-null  int64
# dtypes: float64(11), int64(3), object(6)
# memory usage: 3.4+ MB

# %%
data_df.to_csv("./Clean/Data_2020.csv")
