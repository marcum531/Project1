# %%
import pandas as pd

# %%
data_df=pd.read_csv("./cleaned_csvs/Cleveland_2018.csv")

# %%
data_df['year'] = pd.DatetimeIndex(data_df['FL_DATE']).year
# data_df.head()

# %%
data_df['month'] = pd.DatetimeIndex(data_df['FL_DATE']).month
# data_df.head()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88536 entries, 0 to 88535
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              88536 non-null  object
#  1   OP_UNIQUE_CARRIER    88536 non-null  object
#  2   ORIGIN               88536 non-null  object
#  3   ORIGIN_CITY_NAME     88536 non-null  object
#  4   DEST                 88536 non-null  object
#  5   DEST_CITY_NAME       88536 non-null  object
#  6   CRS_DEP_TIME         88536 non-null  int64
#  7   DEP_DELAY            86627 non-null  float64
#  8   DEP_DELAY_NEW        86627 non-null  float64
#  9   ARR_TIME             86680 non-null  float64
#  10  ARR_DELAY            86464 non-null  float64
#  11  ARR_DELAY_NEW        86464 non-null  float64
#  12  CANCELLED            88536 non-null  int64
#  13  CARRIER_DELAY        16125 non-null  float64
#  14  WEATHER_DELAY        16125 non-null  float64
#  15  NAS_DELAY            16125 non-null  float64
#  16  SECURITY_DELAY       16125 non-null  float64
#  17  LATE_AIRCRAFT_DELAY  16125 non-null  float64
#  18  year                 88536 non-null  int64
#  19  month                88536 non-null  int64
# dtypes: float64(10), int64(4), object(6)
# memory usage: 13.5+ MB

# %%
# Delete Unwated Columns

# %%
data_df
# Out:
#           FL_DATE OP_UNIQUE_CARRIER ORIGIN  ORIGIN_CITY_NAME DEST  \
# 0        1/1/2018                B6    CLE     Cleveland, OH  BOS
# 1        1/1/2018                B6    BOS        Boston, MA  CLE
# 2        1/1/2018                B6    CLE     Cleveland, OH  BOS
# 3        1/1/2018                B6    BOS        Boston, MA  CLE
# 4        1/1/2018                B6    CLE     Cleveland, OH  FLL
# ...           ...               ...    ...               ...  ...
# 88531  12/31/2018                OO    DTW       Detroit, MI  CLE
# 88532  12/31/2018                AA    CLE     Cleveland, OH  PHL
# 88533  12/31/2018                AA    PHL  Philadelphia, PA  CLE
# 88534  12/31/2018                AA    CLE     Cleveland, OH  CLT
# 88535  12/31/2018                AA    CLT     Charlotte, NC  CLE
#
#             DEST_CITY_NAME  CRS_DEP_TIME  DEP_DELAY  DEP_DELAY_NEW  ARR_TIME  \
# 0               Boston, MA          1022       -7.0            0.0    1214.0
# 1            Cleveland, OH           732        3.0            3.0     930.0
# 2               Boston, MA          1859       -7.0            0.0    2039.0
# 3            Cleveland, OH          1618       -6.0            0.0    1806.0
# 4      Fort Lauderdale, FL           713       30.0           30.0    1053.0
# ...                    ...           ...        ...            ...       ...
# 88531        Cleveland, OH           830      -11.0            0.0     907.0
# 88532     Philadelphia, PA           546       -6.0            0.0     648.0
# 88533        Cleveland, OH          1540       12.0           12.0    1742.0
# 88534        Charlotte, NC           951       -8.0            0.0    1113.0
# 88535        Cleveland, OH           735       -7.0            0.0     853.0
#
#        ARR_DELAY  ARR_DELAY_NEW  CANCELLED  CARRIER_DELAY  WEATHER_DELAY  \
# 0           12.0           12.0          0            NaN            NaN
# 1          -11.0            0.0          0            NaN            NaN
# 2           -1.0            0.0          0            NaN            NaN
# 3          -18.0            0.0          0            NaN            NaN
# 4           44.0           44.0          0            0.0           30.0
# ...          ...            ...        ...            ...            ...
# 88531      -35.0            0.0          0            NaN            NaN
# 88532      -40.0            0.0          0            NaN            NaN
# 88533       22.0           22.0          0           12.0            0.0
# 88534      -33.0            0.0          0            NaN            NaN
# 88535      -16.0            0.0          0            NaN            NaN
#
#        NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  year  month
# 0            NaN             NaN                  NaN  2018      1
# 1            NaN             NaN                  NaN  2018      1
# 2            NaN             NaN                  NaN  2018      1
# 3            NaN             NaN                  NaN  2018      1
# 4           14.0             0.0                  0.0  2018      1
# ...          ...             ...                  ...   ...    ...
# 88531        NaN             NaN                  NaN  2018     12
# 88532        NaN             NaN                  NaN  2018     12
# 88533       10.0             0.0                  0.0  2018     12
# 88534        NaN             NaN                  NaN  2018     12
# 88535        NaN             NaN                  NaN  2018     12
#
# [88536 rows x 20 columns]

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88536 entries, 0 to 88535
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              88536 non-null  object
#  1   OP_UNIQUE_CARRIER    88536 non-null  object
#  2   ORIGIN               88536 non-null  object
#  3   ORIGIN_CITY_NAME     88536 non-null  object
#  4   DEST                 88536 non-null  object
#  5   DEST_CITY_NAME       88536 non-null  object
#  6   CRS_DEP_TIME         88536 non-null  int64
#  7   DEP_DELAY            86627 non-null  float64
#  8   DEP_DELAY_NEW        86627 non-null  float64
#  9   ARR_TIME             86680 non-null  float64
#  10  ARR_DELAY            86464 non-null  float64
#  11  ARR_DELAY_NEW        86464 non-null  float64
#  12  CANCELLED            88536 non-null  int64
#  13  CARRIER_DELAY        16125 non-null  float64
#  14  WEATHER_DELAY        16125 non-null  float64
#  15  NAS_DELAY            16125 non-null  float64
#  16  SECURITY_DELAY       16125 non-null  float64
#  17  LATE_AIRCRAFT_DELAY  16125 non-null  float64
#  18  year                 88536 non-null  int64
#  19  month                88536 non-null  int64
# dtypes: float64(10), int64(4), object(6)
# memory usage: 13.5+ MB

# %%
data_df.to_csv("./Clean/Data_2018.csv")
